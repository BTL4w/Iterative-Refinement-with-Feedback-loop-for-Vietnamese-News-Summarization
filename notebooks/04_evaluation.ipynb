# %% [markdown]
# # Phase 1.4: Vietnamese Evaluator
#
# Test và đánh giá chất lượng summaries với:
# - **ROUGE scores** (lexical matching)
# - **BERTScore** (semantic similarity với PhoBERT)
# - **Hybrid scoring** (Faithfulness + Coverage)
# - **Hallucination detection** (sentence-level)

# %% [markdown]
# ## 1. Setup & Imports

# %%
import sys
import os

# Add src to path
sys.path.insert(0, '../src')

from evaluator import VietnameseEvaluator
from extractive import ExtractiveModel
from abstractive import AbstractiveModel
from data_loader import VietNewsDataset

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✓ Imports successful")
